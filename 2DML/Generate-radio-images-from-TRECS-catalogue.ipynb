# %%
import numpy as np
import galsim
from astropy.io import ascii
from astropy.io import fits
import matplotlib.pyplot as plt
from scipy import random
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-96b96780dd63> in <module>
#       1 import numpy as np
# ----> 2 import galsim
#       3 from astropy.io import ascii
#       4 from astropy.io import fits
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'galsim'

# %%
imgsize=96

# %%
big_fft_params=galsim.GSParams(maximum_fft_size=81488)
pixelscale=0.24 # size of pixel in arcsec
stampimage = galsim.ImageF(imgsize, imgsize, scale=pixelscale)
b=galsim.BoundsI(1,imgsize,1,imgsize)
stamp=stampimage[b]

# %% [markdown]
# ## 1-Simulating SFG at 1400 MHz

# %% [markdown]
# ###### Opening T-RECS catalogue (from Bonaldi et al. 2018)

# %%
#catalogsfg=fits.open('catalogue_SFGs_complete_deep.fits')
catalogsfg=fits.open('catalogue_SFGs_complete_wide1.fits')

catalogsfg.info()
cat1=catalogsfg[1]
catdatasfg=cat1.data
# Out:
# Filename: catalogue_SFGs_complete_wide1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  Catalogue     1 BinTableHDU    197   4418708R x 47C   [1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E]

# %% [markdown]
# ##### Randomly draw nobj among the whole SFG catalogue with condition on size

# %%
flux1400sfg=catdatasfg['I1400']  # flux density at 1400 MHz
sizesfg=catdatasfg['size'] # angular size on the sky (in arcsec)
e1=catdatasfg['e1']  # first ellipticity
e2=catdatasfg['e2']  # second ellipticity

# %%
plt.plot(sizesfg/pixelscale,'.')
#plt.ylim([0,10])

# %%
filterobj=np.logical_and(sizesfg > 10*pixelscale, sizesfg <70*pixelscale)
filterobj2=np.where(filterobj == True)[0]

# %%
filterobj[0:10]
# Out:
# array([False,  True,  True,  True,  True, False, False, False,  True,
#        False])

# %%
sizesfg[filterobj2[0:10]]/pixelscale
# Out:
# array([29.959824, 46.919014, 33.560196, 29.755718, 27.567152, 35.495728,
#        22.843374, 11.135371, 29.345383, 13.269678], dtype=float32)

# %%
pixelscale*30
# Out:
# 7.199999999999999

# %%
96*pixelscale
# Out:
# 23.04

# %%
np.min(sizesfg)
# Out:
# 0.021583993

# %%
pixelscale*10
# Out:
# 2.4

# %%
np.random.seed(42)
nobj=300
Ntotobj=len(filterobj2)
print(Ntotobj)
#randidx=np.random.randint(0,Ntotobj,nobj)
# Out:
# 171287

# %%
randidx=np.random.choice(filterobj2,300)

# %%
# Star-forming galaxies (T-RECS)
f=plt.figure()
tabgal=[]
tabgal2=np.empty((300,96,96))
cnt=0
for iobj in randidx:
    gauss_gal=galsim.Gaussian(fwhm=sizesfg[iobj],flux=flux1400sfg[iobj])
    gal = galsim.Exponential(half_light_radius=gauss_gal.half_light_radius, flux=flux1400sfg[iobj], gsparams=big_fft_params)
    ellipticity = galsim.Shear(e1=e1[iobj],e2=e2[iobj])
    gal = gal.shear(ellipticity)
    gal2=gal.drawImage(stamp,scale=pixelscale)
    print(gal2.array.shape)
    tabgal.append(gal2.array)
    plt.figure(iobj+1)
    plt.imshow(gal2.array)
    tabgal2[cnt,:,:]=gal2.array
    cnt=cnt+1
    del gal
# Out:
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# /anaconda2/envs/py36/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)
# (96, 96)

# %%
plt.imshow(tabgal2[50,:,:])

# %%
np.array(tabgal).shape
# Out:
# (300, 96, 96)

# %%
np.savez("Cat-SFG-17-01-2020.npz",nobj=nobj,listgal=np.array(tabgal2),flux1400sfg=flux1400sfg[randidx],sizesfg=sizesfg[randidx],randidx=randidx,e1=e1[randidx],e2=e2[randidx])
